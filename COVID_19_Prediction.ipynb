# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyanshiii-23/Self---Projects/blob/main/COVID_19_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1) IMPORTING LIBRARIES

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D,Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 2) CLONING DATASET

# %%
# CLONING THE DATASET FROM THE GITHUB REPOSITORY
# !git clone https://github.com/RishitToteja/Chext-X-ray-Images-Data-Set.git
# Out:
# Cloning into 'Chext-X-ray-Images-Data-Set'...
# remote: Enumerating objects: 2319, done.
# remote: Total 2319 (delta 0), reused 0 (delta 0), pack-reused 2319 (from 1)
# Receiving objects: 100% (2319/2319), 1.31 GiB | 16.82 MiB/s, done.
# Updating files: 100% (2296/2296), done.

# %%
import os

main_dir = "/content/Chext-X-ray-Images-Data-Set/DataSet/Data"

# SETTING TRAIN AND TEST DIRECTORY
train_dir = os.path.join(main_dir, "train")
test_dir = os.path.join(main_dir, "test")

#SETING DIRECTORY FOR COVID AND NORMAL IMAGES DIRECTORY
train_covid_dir = os.path.join(train_dir, "COVID19")
train_normal_dir = os.path.join(train_dir, "NORMAL")

test_covid_dir = os.path.join(test_dir, "COVID19")
test_normal_dir = os.path.join(test_dir, "NORMAL")

# %%
# MAKING SEPERATE FILES :
train_covid_names = os.listdir(train_covid_dir)
train_normal_names = os.listdir(train_normal_dir)

test_covid_names = os.listdir(test_covid_dir)
test_normal_names = os.listdir(test_normal_dir)

# %% [markdown]
# # 3) PERFORMING DATA VISUALIZATION

# %%
import matplotlib.image as mpimg

rows = 4
columns = 4

fig = plt.gcf()
fig.set_size_inches(12,12)

covid_img = [os.path.join(train_covid_dir, filename) for filename in train_covid_names[0:8]]
normal_img = [os.path.join(train_normal_dir, filename) for filename in train_normal_names[0:8]]

print(covid_img)
print(normal_img)

merged_img = covid_img + normal_img

for i, img_path in enumerate(merged_img):
  title = img_path.split("/", 6)[6]
  plot = plt.subplot(rows, columns, i+1)
  plot.axis("Off")
  img = mpimg.imread(img_path)
  plot.set_title(title, fontsize = 11)
  plt.imshow(img, cmap= "gray")

plt.show()
# Out:
# ['/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(188).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(279).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(179).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(104).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(141).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(4).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(540).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(340).jpg']
# ['/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(407).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(563).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(1255).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(1177).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(1079).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(800).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(193).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(59).jpg']

# %% [markdown]
# # 4) DATA PREPROCESSING AND AUGMENTATION

# %%
# CREATING TRAINING, TESTING AND VALIDATION BATCHES

dgen_train = ImageDataGenerator(rescale = 1./255,
                                validation_split = 0.2,
                                zoom_range = 0.2,
                                horizontal_flip = True)

dgen_validation = ImageDataGenerator(rescale = 1./255,
                                     )

dgen_test = ImageDataGenerator(rescale = 1./255,
                              )

train_generator = dgen_train.flow_from_directory(train_dir,
                                                 target_size = (150, 150),
                                                 subset = 'training',
                                                 batch_size = 32,
                                                 class_mode = 'binary')
validation_generator = dgen_train.flow_from_directory(train_dir,
                                                      target_size = (150, 150),
                                                      subset = "validation",
                                                      batch_size = 32,
                                                      class_mode = "binary")
test_generator = dgen_test.flow_from_directory(test_dir,
                                               target_size = (150, 150),
                                               batch_size = 32,
                                               class_mode = "binary")
# Out:
# Found 1449 images belonging to 2 classes.
# Found 362 images belonging to 2 classes.
# Found 484 images belonging to 2 classes.

# %%
print("Class Labels are: ", train_generator.class_indices)
print("Image shape is : ", train_generator.image_shape)
# Out:
# Class Labels are:  {'COVID19': 0, 'NORMAL': 1}
# Image shape is :  (150, 150, 3)

# %% [markdown]
# # 5) BUILDING CONVOLUTIONAL NEURAL NETWORK MODEL

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D

model = Sequential()

# 1) CONVOLUTIONAL LAYER - 1
model.add(Conv2D(32, (5,5), padding = "same", activation = "relu", input_shape = train_generator.image_shape))

# 2) POOLING LAYER - 1
model.add(MaxPooling2D(pool_size=(2,2)))

# 3) DROPOUT LAYER -2
model.add(Dropout(0.5))

# 4) CONVOLUTIONAL LAYER - 2
model.add(Conv2D(64, (5,5), padding = "same", activation = "relu"))

# 5) POOLING LAYER - 2
model.add(MaxPooling2D(pool_size=(2,2)))

# 6) DROPOUT LAYER - 2
model.add(Dropout(0.5))

# 7) FLATTENING LAYER TO 2D SHAPE
model.add(Flatten())

# 8) ADDING A DENSE LAYER
model.add(Dense(256, activation = 'relu'))

# 9 DROPOUT LAYER - 3
model.add(Dropout(0.5))

# 10) FINAL OUTPUT LAYER
model.add(Dense(1, activation = 'sigmoid'))

### PRINTING MODEL SUMMARY
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 150, 150, 32)   │         2,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 75, 75, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 75, 75, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 75, 75, 64)     │        51,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 37, 37, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 37, 37, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 87616)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │    22,429,952 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,483,905 (85.77 MB)
#  Trainable params: 22,483,905 (85.77 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # 6) COMPILING AND TRAINING THE NEURAL NETWORK MODEL

# %%
# COMPILING THE MODEL

model.compile(Adam(learning_rate = 0.001), loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# TRAINING THE MODEL
history = model.fit(train_generator,
                    epochs = 35,
                    validation_data = validation_generator)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.6630 - loss: 1.6853 - val_accuracy: 0.9006 - val_loss: 0.4149
# Epoch 2/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 41s 888ms/step - accuracy: 0.9347 - loss: 0.2088 - val_accuracy: 0.9586 - val_loss: 0.2359
# Epoch 3/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 43s 930ms/step - accuracy: 0.9551 - loss: 0.1342 - val_accuracy: 0.9475 - val_loss: 0.2015
# Epoch 4/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 41s 883ms/step - accuracy: 0.9485 - loss: 0.1505 - val_accuracy: 0.8867 - val_loss: 0.3321
# Epoch 5/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 41s 886ms/step - accuracy: 0.9485 - loss: 0.1671 - val_accuracy: 0.9779 - val_loss: 0.1446
# Epoch 6/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 41s 898ms/step - accuracy: 0.9593 - loss: 0.1250 - val_accuracy: 0.9751 - val_loss: 0.1150
# Epoch 7/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 42s 923ms/step - accuracy: 0.9508 - loss: 0.1089 - val_accuracy: 0.9641 - val_loss: 0.0978
# Epoch 8/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 41s 896ms/step - accuracy: 0.9514 - loss: 0.1298 - val_accuracy: 0.9613 - val_loss: 0.1227
# Epoch 9/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 81s 880ms/step - accuracy: 0.9525 - loss: 0.1489 - val_accuracy: 0.9641 - val_loss: 0.0965
# Epoch 10/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 41s 900ms/step - accuracy: 0.9585 - loss: 0.0938 - val_accuracy: 0.9669 - val_loss: 0.1134
# Epoch 11/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 41s 883ms/step - accuracy: 0.9689 - loss: 0.1002 - val_accuracy: 0.9696 - val_loss: 0.0855
# Epoch 12/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 45s 976ms/step - accuracy: 0.9632 - loss: 0.0997 - val_accuracy: 0.9475 - val_loss: 0.1248
# Epoch 13/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 40s 878ms/step - accuracy: 0.9600 - loss: 0.1148 - val_accuracy: 0.9724 - val_loss: 0.0904
# Epoch 14/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 41s 889ms/step - accuracy: 0.9830 - loss: 0.0578 - val_accuracy: 0.9696 - val_loss: 0.0920
# Epoch 15/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 43s 948ms/step - accuracy: 0.9715 - loss: 0.0683 - val_accuracy: 0.9834 - val_loss: 0.0654
# Epoch 16/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 41s 899ms/step - accuracy: 0.9675 - loss: 0.0865 - val_accuracy: 0.9862 - val_loss: 0.0724
# Epoch 17/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 41s 896ms/step - accuracy: 0.9690 - loss: 0.0825 - val_accuracy: 0.9807 - val_loss: 0.0875
# Epoch 18/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 40s 880ms/step - accuracy: 0.9757 - loss: 0.0704 - val_accuracy: 0.9807 - val_loss: 0.0522
# Epoch 19/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 41s 888ms/step - accuracy: 0.9654 - loss: 0.0886 - val_accuracy: 0.9751 - val_loss: 0.0802
# Epoch 20/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 41s 891ms/step - accuracy: 0.9837 - loss: 0.0565 - val_accuracy: 0.9696 - val_loss: 0.1052
# Epoch 21/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 40s 875ms/step - accuracy: 0.9777 - loss: 0.0731 - val_accuracy: 0.9807 - val_loss: 0.0690
# Epoch 22/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 40s 879ms/step - accuracy: 0.9821 - loss: 0.0645 - val_accuracy: 0.9751 - val_loss: 0.0636
# Epoch 23/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 41s 902ms/step - accuracy: 0.9666 - loss: 0.0884 - val_accuracy: 0.9890 - val_loss: 0.0695
# Epoch 24/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 40s 875ms/step - accuracy: 0.9875 - loss: 0.0539 - val_accuracy: 0.9834 - val_loss: 0.0573
# Epoch 25/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 40s 874ms/step - accuracy: 0.9827 - loss: 0.0588 - val_accuracy: 0.9309 - val_loss: 0.1341
# Epoch 26/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 41s 900ms/step - accuracy: 0.9718 - loss: 0.0790 - val_accuracy: 0.9862 - val_loss: 0.0622
# Epoch 27/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 41s 891ms/step - accuracy: 0.9843 - loss: 0.0582 - val_accuracy: 0.9530 - val_loss: 0.1366
# Epoch 28/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 40s 884ms/step - accuracy: 0.9797 - loss: 0.0616 - val_accuracy: 0.9807 - val_loss: 0.0734
# Epoch 29/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 41s 891ms/step - accuracy: 0.9930 - loss: 0.0371 - val_accuracy: 0.9807 - val_loss: 0.0624
# Epoch 30/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 40s 879ms/step - accuracy: 0.9870 - loss: 0.0400 - val_accuracy: 0.9807 - val_loss: 0.0846
# Epoch 31/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 41s 888ms/step - accuracy: 0.9723 - loss: 0.0879 - val_accuracy: 0.9862 - val_loss: 0.0605
# Epoch 32/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 41s 885ms/step - accuracy: 0.9890 - loss: 0.0361 - val_accuracy: 0.9862 - val_loss: 0.0641
# Epoch 33/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 40s 876ms/step - accuracy: 0.9737 - loss: 0.0619 - val_accuracy: 0.9862 - val_loss: 0.0514
# Epoch 34/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 40s 878ms/step - accuracy: 0.9884 - loss: 0.0370 - val_accuracy: 0.9917 - val_loss: 0.0418
# Epoch 35/35
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 42s 900ms/step - accuracy: 0.9833 - loss: 0.0666 - val_accuracy: 0.9807 - val_loss: 0.0798

# %% [markdown]
# # 7) PERFORMING EVALUATION

# %%
# KEYS OF HISTORY OBJECT
history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# PLOT GRAPH BETWEEN TRAINING AND VALIDATION LOSS
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Training', 'Validation'])
plt.title("Training and validation losses")
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
# PLOT GRAPH BETWEEN TRAINING AND VALIDATION ACCURACY
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['Training', 'Validation'])
plt.title("Training and validation accuracy")
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
# GETTING TEST ACCURACY AND LOSS

test_loss, test_acc = model.evaluate(test_generator)
print("Test Set Loss : ", test_loss)
print("Test Set Accuracy : ", test_acc)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 9s 593ms/step - accuracy: 0.9799 - loss: 0.0585
# Test Set Loss :  0.05745217949151993
# Test Set Accuracy :  0.9814049601554871

# %% [markdown]
# # 9) PREDICTION ON NEW DATA (UPLOAD FILES)

# %%
from google.colab import files
from keras.preprocessing import image
img_path = '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/test/NORMAL/NORMAL(10).jpg'
img = image.load_img(img_path, target_size = (150,150))
images = image.img_to_array(img)
images = np.expand_dims(images, axis = 0)
prediction = model.predict(images)

if prediction == 0:
    print("The report is COVID-19 Positive")
else:
    print("The report is COVID-19 Negative")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# The report is COVID-19 Negative

# %%
model.save("model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
